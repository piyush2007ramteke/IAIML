# %% [markdown]
# <a href="https://colab.research.google.com/github/piyush2007ramteke/IAIML/blob/main/practicle1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
attendance = float(input("enter your attendance"))
if attendance >= 75:
  print("student is eligible")
else:
  print("student is not eligible")
# Out:
# enter your attendance74
# student is not eligible
